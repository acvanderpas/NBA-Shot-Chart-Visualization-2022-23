# %% [markdown]
# # Load in necessary libraries

# %%
import pandas as pd
import numpy as np
import time

from scipy.stats import norm, gaussian_kde, percentileofscore

pd.options.display.max_columns = None
from nba_api.stats.static import players
from nba_api.stats.endpoints import shotchartdetail
from nba_api.stats.endpoints import playercareerstats

# %% [markdown]
# # Define function to pull shot chart data from NBA API, specifying player name and season as parameters

# %%
def get_player_shotchartdetail(player_name, season_id):
    """
    Parameters
    ----------
    player_name: name of the player with Capital
    season_id: ex. 2012-13
    """
    
    # player dictionary
    nba_players = players.get_players()
    player_dict = [player for player in nba_players if player['full_name'] == player_name][0]
    
    # career df
    career = playercareerstats.PlayerCareerStats(player_id=player_dict['id'])
    career_df = career.get_data_frames()[0]
    
    # team id during the season
    team_id = career_df[career_df['SEASON_ID'] == season_id]['TEAM_ID']
    
    # shotchardtdetail endpoint
    shotchartlist = shotchartdetail.ShotChartDetail(team_id=int(team_id), 
                                                   player_id=int(player_dict['id']), 
                                                   season_type_all_star='Regular Season', 
                                                   season_nullable=season_id,
                                                   context_measure_simple="FGA").get_data_frames()
    
    return shotchartlist[0], shotchartlist[1]

# %% [markdown]
# # Example run using Giannis Antetokounmpo during the 2022-23 NBA regular season

# %%
player_shotchart_df, league_avg = get_player_shotchartdetail('Giannis Antetokounmpo', '2022-23')
pd.DataFrame.head(player_shotchart_df)
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 0  Shot Chart Detail  0022200015             35     203507
# 1  Shot Chart Detail  0022200015             49     203507
# 2  Shot Chart Detail  0022200015            131     203507
# 3  Shot Chart Detail  0022200015            140     203507
# 4  Shot Chart Detail  0022200015            201     203507
#
#              PLAYER_NAME     TEAM_ID        TEAM_NAME  PERIOD  \
# 0  Giannis Antetokounmpo  1610612749  Milwaukee Bucks       1
# 1  Giannis Antetokounmpo  1610612749  Milwaukee Bucks       1
# 2  Giannis Antetokounmpo  1610612749  Milwaukee Bucks       1
# 3  Giannis Antetokounmpo  1610612749  Milwaukee Bucks       1
# 4  Giannis Antetokounmpo  1610612749  Milwaukee Bucks       2
#
#    MINUTES_REMAINING  SECONDS_REMAINING EVENT_TYPE  \
# 0                  8                 44  Made Shot
# 1                  7                 30  Made Shot
# 2                  1                 20  Made Shot
# 3                  0                 30  Made Shot
# 4                  7                 28  Made Shot
#
#                       ACTION_TYPE       SHOT_TYPE    SHOT_ZONE_BASIC  \
# 0              Running Layup Shot  2PT Field Goal    Restricted Area
# 1  Running Finger Roll Layup Shot  2PT Field Goal    Restricted Area
# 2                       Jump Shot  3PT Field Goal  Above the Break 3
# 3                Pullup Jump shot  2PT Field Goal          Mid-Range
# 4  Running Finger Roll Layup Shot  2PT Field Goal    Restricted Area
#
#          SHOT_ZONE_AREA  SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  \
# 0             Center(C)  Less Than 8 ft.              2     27     11
# 1             Center(C)  Less Than 8 ft.              1     -9      9
# 2  Left Side Center(LC)          24+ ft.             27   -157    227
# 3  Left Side Center(LC)        16-24 ft.             19   -110    162
# 4             Center(C)  Less Than 8 ft.              3     18     31
#
#    SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG GAME_DATE  HTM  VTM
# 0                    1               1  20221020  PHI  MIL
# 1                    1               1  20221020  PHI  MIL
# 2                    1               1  20221020  PHI  MIL
# 3                    1               1  20221020  PHI  MIL
# 4                    1               1  20221020  PHI  MIL

# %% [markdown]
# # Create list of all active NBA players for 2022-23 regular season

# %%
from nba_api.stats.static  import players
player_dict = players.get_active_players()

# %%
player_name = [d['full_name'] for d in player_dict]

player_name[:10]
# Out:
# ['Precious Achiuwa',
#  'Steven Adams',
#  'Bam Adebayo',
#  'Ochai Agbaji',
#  'Santi Aldama',
#  'Nickeil Alexander-Walker',
#  'Grayson Allen',
#  'Jarrett Allen',
#  'Jose Alvarado',
#  'Kyle Anderson']

# %% [markdown]
# # Pull shot chart data for all active NBA players for the 2022-23 NBA regular season from NBA API. Delay was implemented to avoid time out

# %%
shotchart = pd.DataFrame()
for i in range(582):
    try:
        player_shotchart_df, league_avg = get_player_shotchartdetail(player_name[i], '2022-23')
        shotchart = pd.concat([shotchart, player_shotchart_df])
        time.sleep(3)
    except (TypeError, IndexError):
        pass
    
shotchart
# Out:
#              GRID_TYPE     GAME_ID GAME_EVENT_ID PLAYER_ID       PLAYER_NAME  \
# 0    Shot Chart Detail  0022200008            89   1630173  Precious Achiuwa
# 1    Shot Chart Detail  0022200008           113   1630173  Precious Achiuwa
# 2    Shot Chart Detail  0022200008           474   1630173  Precious Achiuwa
# 3    Shot Chart Detail  0022200008           511   1630173  Precious Achiuwa
# 4    Shot Chart Detail  0022200008           542   1630173  Precious Achiuwa
# ..                 ...         ...           ...       ...               ...
# 509  Shot Chart Detail  0022201229           259   1627826       Ivica Zubac
# 510  Shot Chart Detail  0022201229           304   1627826       Ivica Zubac
# 511  Shot Chart Detail  0022201229           360   1627826       Ivica Zubac
# 512  Shot Chart Detail  0022201229           416   1627826       Ivica Zubac
# 513  Shot Chart Detail  0022201229           422   1627826       Ivica Zubac
#
#         TEAM_ID        TEAM_NAME PERIOD MINUTES_REMAINING SECONDS_REMAINING  \
# 0    1610612761  Toronto Raptors      1                 4                50
# 1    1610612761  Toronto Raptors      1                 3                59
# 2    1610612761  Toronto Raptors      3                 3                 8
# 3    1610612761  Toronto Raptors      3                 0                41
# 4    1610612761  Toronto Raptors      4                10                18
# ..          ...              ...    ...               ...               ...
# 509  1610612746      LA Clippers      2                 4                57
# 510  1610612746      LA Clippers      2                 1                13
# 511  1610612746      LA Clippers      3                10                19
# 512  1610612746      LA Clippers      3                 5                48
# 513  1610612746      LA Clippers      3                 5                13
#
#       EVENT_TYPE                     ACTION_TYPE       SHOT_TYPE  \
# 0    Missed Shot                       Jump Shot  3PT Field Goal
# 1    Missed Shot              Running Layup Shot  2PT Field Goal
# 2    Missed Shot              Floating Jump shot  2PT Field Goal
# 3      Made Shot  Cutting Finger Roll Layup Shot  2PT Field Goal
# 4      Made Shot                       Jump Shot  3PT Field Goal
# ..           ...                             ...             ...
# 509    Made Shot              Putback Layup Shot  2PT Field Goal
# 510  Missed Shot                       Hook Shot  2PT Field Goal
# 511    Made Shot                       Dunk Shot  2PT Field Goal
# 512    Made Shot              Floating Jump shot  2PT Field Goal
# 513    Made Shot                       Hook Shot  2PT Field Goal
#
#            SHOT_ZONE_BASIC        SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0        Above the Break 3  Left Side Center(LC)          24+ ft.
# 1          Restricted Area             Center(C)  Less Than 8 ft.
# 2    In The Paint (Non-RA)             Center(C)         8-16 ft.
# 3          Restricted Area             Center(C)  Less Than 8 ft.
# 4        Above the Break 3  Left Side Center(LC)          24+ ft.
# ..                     ...                   ...              ...
# 509  In The Paint (Non-RA)             Center(C)  Less Than 8 ft.
# 510        Restricted Area             Center(C)  Less Than 8 ft.
# 511        Restricted Area             Center(C)  Less Than 8 ft.
# 512  In The Paint (Non-RA)             Center(C)         8-16 ft.
# 513        Restricted Area             Center(C)  Less Than 8 ft.
#
#     SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG SHOT_MADE_FLAG GAME_DATE  \
# 0              27  -159   221                   1              0  20221019
# 1               2     6    22                   1              0  20221019
# 2               8    22    79                   1              0  20221019
# 3               2    -2    21                   1              1  20221019
# 4              25  -200   153                   1              1  20221019
# ..            ...   ...   ...                 ...            ...       ...
# 509             5    -1    58                   1              1  20230409
# 510             3    34    18                   1              0  20230409
# 511             0     4    -1                   1              1  20230409
# 512             9    11    93                   1              1  20230409
# 513             1    -6    15                   1              1  20230409
#
#      HTM  VTM
# 0    TOR  CLE
# 1    TOR  CLE
# 2    TOR  CLE
# 3    TOR  CLE
# 4    TOR  CLE
# ..   ...  ...
# 509  PHX  LAC
# 510  PHX  LAC
# 511  PHX  LAC
# 512  PHX  LAC
# 513  PHX  LAC
#
# [190781 rows x 24 columns]

# %% [markdown]
# # Read dataframe of NBA shot chart data into CSV file

# %%
shotchart.to_csv("nba_shot_data.csv", index = False)
